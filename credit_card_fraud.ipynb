# %%
pip install pandas numpy matplotlib seaborn scikit-learn jupyter imbalanced-learn
# Out:
# Requirement already satisfied: pandas in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: seaborn in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (1.6.1)
# Requirement already satisfied: jupyter in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (1.1.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: notebook in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (7.4.3)
# Requirement already satisfied: jupyter-console in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\rafa\appdata\roaming\python\python313\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (4.4.3)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: six>=1.5 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from jupyter-console->jupyter) (3.0.51)
# Requirement already satisfied: pygments in c:\users\rafa\appdata\roaming\python\python313\site-packages (from jupyter-console->jupyter) (2.19.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (80.9.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.9.0)
# Requirement already satisfied: certifi in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: colorama in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\rafa\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (310)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.24.0)
# Requirement already satisfied: requests>=2.31 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\rafa\appdata\roaming\python\python313\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (4.13.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.4.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rafa\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\rafa\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\rafa\appdata\local\programs\python\python313\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250516)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
# Successfully installed imbalanced-learn-0.13.0 sklearn-compat-0.1.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from imblearn.under_sampling import RandomUnderSampler

# %%
df = pd.read_csv("creditcard.csv")
print(df.info())
print(df['Class'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv("creditcard.csv")
#       2 print(df.info())
#       3 print(df['Class'].value_counts())
#
# File c:\Users\Rafa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Rafa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Rafa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Rafa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Rafa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'creditcard.csv'
